# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import scienceplots
from src.styles import set_plot_style
from src.plots import *
from src.timeline import *
from src.utils import load_and_prepare_metadata
set_plot_style("prism_rain")
from src.utils import _proc_from_path, _file_index, _read_measurement

# %%
METADATA_CSV = "metadata/Alisson_12_sept/metadata.csv"          # path to the table you pasted
BASE_DIR     = Path(".")             # where the raw CSVs live, e.g. "Alisson_04_sept/"
CHIP_NUMBER  = 75.0 
meta = load_and_prepare_metadata(METADATA_CSV, CHIP_NUMBER)
tag = Path(METADATA_CSV).stem


# Reuse your existing plotter on this subset
plot_ivg_sequence(meta, BASE_DIR, tag)
# Out:
# saved figs/Encap75_IVg_sequence_metadata.png

# %%
good_ivgs = [6,7]  # the _NN.csv numbers you want

meta_only_good_ivg = meta.filter(
    (pl.col("proc") == "IVg") & pl.col("file_idx").is_in(good_ivgs)
)

# Reuse your existing plotter on this subset
plot_ivg_sequence(meta_only_good_ivg, BASE_DIR, tag)
# Out:
# saved figs/Encap75_IVg_sequence_metadata.png

# %%
good_ivgs = [7,8]  # the _NN.csv numbers you want

meta_only_good_ivg = meta.filter(
    (pl.col("proc") == "IVg") & pl.col("file_idx").is_in(good_ivgs)
)

# Reuse your existing plotter on this subset
plot_ivg_sequence(meta_only_good_ivg, BASE_DIR, tag)
# Out:
# saved figs/Encap75_IVg_sequence_metadata.png

# %%
good_ivgs = [9,10]  # the _NN.csv numbers you want

meta_only_good_ivg = meta.filter(
    (pl.col("proc") == "IVg") & pl.col("file_idx").is_in(good_ivgs)
)

# Reuse your existing plotter on this subset
plot_ivg_sequence(meta_only_good_ivg, BASE_DIR, tag)
# Out:
# saved figs/Encap75_IVg_sequence_metadata.png

# %%
good_ivgs = [10,11]  # the _NN.csv numbers you want

meta_only_good_ivg = meta.filter(
    (pl.col("proc") == "IVg") & pl.col("file_idx").is_in(good_ivgs)
)

# Reuse your existing plotter on this subset
plot_ivg_sequence(meta_only_good_ivg, BASE_DIR, tag)
# Out:
# saved figs/Encap75_IVg_sequence_metadata.png

# %%
good_ivgs = [11,12,13]  # the _NN.csv numbers you want

meta_only_good_ivg = meta.filter(
    (pl.col("proc") == "IVg") & pl.col("file_idx").is_in(good_ivgs)
)

# Reuse your existing plotter on this subset
plot_ivg_sequence(meta_only_good_ivg, BASE_DIR, tag)
# Out:
# saved figs/Encap75_IVg_sequence_metadata.png

# %%
good_ivgs = [16,17]  # the _NN.csv numbers you want

meta_only_good_ivg = meta.filter(
    (pl.col("proc") == "IVg") & pl.col("file_idx").is_in(good_ivgs)
)

# Reuse your existing plotter on this subset
plot_ivg_sequence(meta_only_good_ivg, BASE_DIR, tag)
# Out:
# saved figs/Encap75_IVg_sequence_metadata.png

# %%
good_ivgs = [17,18]  # the _NN.csv numbers you want

meta_only_good_ivg = meta.filter(
    (pl.col("proc") == "IVg") & pl.col("file_idx").is_in(good_ivgs)
)

# Reuse your existing plotter on this subset
plot_ivg_sequence(meta_only_good_ivg, BASE_DIR, tag)
# Out:
# saved figs/Encap75_IVg_sequence_metadata.png

# %%
good_ivgs = [18,19,20]  # the _NN.csv numbers you want

meta_only_good_ivg = meta.filter(
    (pl.col("proc") == "IVg") & pl.col("file_idx").is_in(good_ivgs)
)

# Reuse your existing plotter on this subset
plot_ivg_sequence(meta_only_good_ivg, BASE_DIR, tag)
# Out:
# saved figs/Encap75_IVg_sequence_metadata.png

# %%
plot_its_by_vg(meta, BASE_DIR, tag, vgs=[-3.0], wavelengths=[365.0])
# Out:
# saved figs/chip75_ITS_overlay_Vgm3p0_365nm_metadata.png

# %%
plot_its_by_vg(meta, BASE_DIR, tag, vgs=[3.0], wavelengths=[365.0])
# Out:
# saved figs/chip75_ITS_overlay_Vg3p0_365nm_metadata.png

# %%
plot_its_by_vg(meta, BASE_DIR, tag, vgs=[-3.0], wavelengths=[455.0]) 
plot_its_by_vg(meta, BASE_DIR, tag, vgs=[3.0], wavelengths=[455.0])
# Out:
# saved figs/chip75_ITS_overlay_Vgm3p0_455nm_metadata.png
# saved figs/chip75_ITS_overlay_Vg3p0_455nm_metadata.png

# %%
plot_its_by_vg(meta, BASE_DIR, tag, vgs=[-3.0], wavelengths=[565.0]) 
plot_its_by_vg(meta, BASE_DIR, tag, vgs=[3.0], wavelengths=[565.0])
# Out:
# saved figs/chip75_ITS_overlay_Vgm3p0_565nm_metadata.png
# saved figs/chip75_ITS_overlay_Vg3p0_565nm_metadata.png

# %%
BASE = Path("raw_data")
CSV  = "metadata/Alisson_12_sept/metadata.csv"
timeline = print_day_timeline(CSV, BASE)
# Out:
# === Day timeline (chronological) ===
#   1  11:14:57  IVg chip 71  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #1           t=    0.0s
#   2  11:16:25  IVg chip 71  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #2  +  87.9s  t=   87.9s
#   3  11:16:55  IVg chip 71  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #3  +  29.6s  t=  117.5s
#   4  11:19:58  IV  chip 71  VG=0.0 V  VSD:-1.0→1.0 (step 0.01)  #1  + 183.9s  t=  301.5s
#   5  11:20:34  IV  chip 71  VG=0.0 V  VSD:-1.0→1.0 (step 0.01)  #2  +  35.5s  t=  336.9s
#   6  12:49:41  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #4  +5347.3s  t= 5684.2s
#   7  13:30:29  LaserCalibration λ=365.0 nm  #1  +2447.8s  t= 8131.9s
#   8  13:39:08  LaserCalibration λ=455.0 nm  #2  + 519.0s  t= 8650.9s
#   9  13:45:34  LaserCalibration λ=565.0 nm  #3  + 386.2s  t= 9037.1s
#  10  13:50:26  LaserCalibration λ=625.0 nm  #4  + 292.2s  t= 9329.4s
#  11  14:30:40  LaserCalibration λ=365.0 nm  #5  +2413.8s  t=11743.2s
#  12  14:45:42  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #5  + 901.4s  t=12644.6s
#  13  14:54:38  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #6  + 536.7s  t=13181.3s
#  14  14:56:03  It  chip 75  VG=-3.0 V  VDS=0.1 V  VL=0.88 V  λ=365.0 nm  period=120.0 s  #1  +  84.3s  t=13265.7s
#  15  14:59:10  It  chip 75  VG=-3.0 V  VDS=0.1 V  VL=1.78 V  λ=365.0 nm  period=120.0 s  #2  + 187.6s  t=13453.2s
#  16  15:02:17  It  chip 75  VG=-3.0 V  VDS=0.1 V  VL=2.74 V  λ=365.0 nm  period=120.0 s  #3  + 187.2s  t=13640.4s
#  17  15:05:25  It  chip 75  VG=-3.0 V  VDS=0.1 V  VL=3.71 V  λ=365.0 nm  period=120.0 s  #4  + 187.1s  t=13827.5s
#  18  15:08:32  It  chip 75  VG=-3.0 V  VDS=0.1 V  VL=4.71 V  λ=365.0 nm  period=120.0 s  #5  + 187.2s  t=14014.8s
#  19  15:25:19  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #7  +1007.1s  t=15021.9s
#  20  15:26:53  It  chip 75  VG=3.0 V  VDS=0.1 V  VL=0.88 V  λ=365.0 nm  period=120.0 s  #6  +  94.4s  t=15116.2s
#  21  15:30:00  It  chip 75  VG=3.0 V  VDS=0.1 V  VL=1.78 V  λ=365.0 nm  period=120.0 s  #7  + 187.0s  t=15303.2s
#  22  15:33:07  It  chip 75  VG=3.0 V  VDS=0.1 V  VL=2.74 V  λ=365.0 nm  period=120.0 s  #8  + 187.2s  t=15490.4s
#  23  15:36:14  It  chip 75  VG=3.0 V  VDS=0.1 V  VL=3.71 V  λ=365.0 nm  period=120.0 s  #9  + 187.0s  t=15677.5s
#  24  15:39:22  It  chip 75  VG=3.0 V  VDS=0.1 V  VL=4.71 V  λ=365.0 nm  period=120.0 s  #10  + 187.1s  t=15864.5s
#  25  16:18:01  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #8  +2319.7s  t=18184.2s
#  26  16:25:30  LaserCalibration λ=455.0 nm  #6  + 449.1s  t=18633.3s
#  27  16:31:24  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #9  + 353.5s  t=18986.8s
#  28  16:32:50  It  chip 75  VG=-3.0 V  VDS=0.1 V  VL=0.9 V  λ=455.0 nm  period=120.0 s  #11  +  86.4s  t=19073.2s
#  29  16:35:57  It  chip 75  VG=-3.0 V  VDS=0.1 V  VL=1.71 V  λ=455.0 nm  period=120.0 s  #12  + 187.1s  t=19260.3s
#  30  16:39:04  It  chip 75  VG=-3.0 V  VDS=0.1 V  VL=2.59 V  λ=455.0 nm  period=120.0 s  #13  + 187.2s  t=19447.5s
#  31  16:42:12  It  chip 75  VG=-3.0 V  VDS=0.1 V  VL=3.47 V  λ=455.0 nm  period=120.0 s  #14  + 187.1s  t=19634.6s
#  32  16:45:19  It  chip 75  VG=-3.0 V  VDS=0.1 V  VL=4.42 V  λ=455.0 nm  period=120.0 s  #15  + 187.5s  t=19822.1s
#  33  16:55:23  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #10  + 604.4s  t=20426.5s
#  34  16:56:31  It  chip 75  VG=3.0 V  VDS=0.1 V  VL=0.9 V  λ=455.0 nm  period=120.0 s  #16  +  67.8s  t=20494.3s
#  35  16:59:38  It  chip 75  VG=3.0 V  VDS=0.1 V  VL=1.71 V  λ=455.0 nm  period=120.0 s  #17  + 187.1s  t=20681.4s
#  36  17:02:46  It  chip 75  VG=3.0 V  VDS=0.1 V  VL=2.59 V  λ=455.0 nm  period=120.0 s  #18  + 187.7s  t=20869.0s
#  37  17:05:53  It  chip 75  VG=3.0 V  VDS=0.1 V  VL=3.47 V  λ=455.0 nm  period=120.0 s  #19  + 187.0s  t=21056.0s
#  38  17:09:01  It  chip 75  VG=3.0 V  VDS=0.1 V  VL=4.42 V  λ=455.0 nm  period=120.0 s  #20  + 187.5s  t=21243.6s
#  39  17:15:58  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #11  + 417.3s  t=21660.9s
#  40  17:21:17  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #12  + 319.7s  t=21980.5s
#  41  17:22:14  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #13  +  56.9s  t=22037.4s
#  42  17:23:43  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #14  +  89.1s  t=22126.5s
#  43  17:45:19  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #15  +1295.6s  t=23422.1s
#  44  17:51:22  LaserCalibration λ=565.0 nm  #7  + 362.6s  t=23784.8s
#  45  17:55:44  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #16  + 262.1s  t=24046.9s
#  46  17:57:02  It  chip 75  VG=-3.0 V  VDS=0.1 V  VL=0.78 V  λ=565.0 nm  period=120.0 s  #21  +  78.5s  t=24125.4s
#  47  18:00:10  It  chip 75  VG=-3.0 V  VDS=0.1 V  VL=1.57 V  λ=565.0 nm  period=120.0 s  #22  + 187.6s  t=24312.9s
#  48  18:03:17  It  chip 75  VG=-3.0 V  VDS=0.1 V  VL=2.44 V  λ=565.0 nm  period=120.0 s  #23  + 187.3s  t=24500.2s
#  49  18:06:24  It  chip 75  VG=-3.0 V  VDS=0.1 V  VL=3.38 V  λ=565.0 nm  period=120.0 s  #24  + 187.1s  t=24687.3s
#  50  18:09:31  It  chip 75  VG=-3.0 V  VDS=0.1 V  VL=4.37 V  λ=565.0 nm  period=120.0 s  #25  + 187.1s  t=24874.4s
#  51  18:19:17  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #17  + 585.4s  t=25459.7s
#  52  18:20:18  It  chip 75  VG=3.0 V  VDS=0.1 V  VL=0.78 V  λ=565.0 nm  period=120.0 s  #26  +  61.0s  t=25520.7s
#  53  18:23:26  It  chip 75  VG=3.0 V  VDS=0.1 V  VL=1.57 V  λ=565.0 nm  period=120.0 s  #27  + 188.1s  t=25708.9s
#  54  18:26:34  It  chip 75  VG=3.0 V  VDS=0.1 V  VL=2.44 V  λ=565.0 nm  period=120.0 s  #28  + 187.8s  t=25896.6s
#  55  18:29:41  It  chip 75  VG=3.0 V  VDS=0.1 V  VL=3.38 V  λ=565.0 nm  period=120.0 s  #29  + 187.0s  t=26083.6s
#  56  18:32:48  It  chip 75  VG=3.0 V  VDS=0.1 V  VL=4.37 V  λ=565.0 nm  period=120.0 s  #30  + 187.2s  t=26270.8s
#  57  18:36:18  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #18  + 210.3s  t=26481.1s
#  58  18:37:51  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #19  +  92.8s  t=26573.9s
#  59  18:38:48  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #20  +  57.1s  t=26631.0s
# ====================================
#
# saved metadata/Alisson_12_sept/metadata_timeline.csv

# %%
plot_its_by_vg_delta(
    meta, BASE_DIR, tag,
    vgs=[-3.0], wavelengths=[365.0],
    baseline_t=60.0, clip_t_min=20.0
)
plot_its_by_vg_delta(
    meta, BASE_DIR, tag,
    vgs=[3.0], wavelengths=[365.0],
    baseline_t=60.0, clip_t_min=20.0
)
# Out:
# saved figs/chip75_ITS_dI_Vgm3p0_365nm_metadata.png
# saved figs/chip75_ITS_dI_Vg3p0_365nm_metadata.png

# %%
plot_its_by_vg_delta(
    meta, BASE_DIR, tag,
    vgs=[-3.0], wavelengths=[455.0],
    baseline_t=60.0, clip_t_min=20.0
)
plot_its_by_vg_delta(
    meta, BASE_DIR, tag,
    vgs=[3.0], wavelengths=[455.0],
    baseline_t=60.0, clip_t_min=20.0
)
# Out:
# saved figs/chip75_ITS_dI_Vgm3p0_455nm_metadata.png
# saved figs/chip75_ITS_dI_Vg3p0_455nm_metadata.png

# %%
plot_its_by_vg_delta(
    meta, BASE_DIR, tag,
    vgs=[-3.0], wavelengths=[565.0],
    baseline_t=60.0, clip_t_min=20.0
)
plot_its_by_vg_delta(
    meta, BASE_DIR, tag,
    vgs=[3.0], wavelengths=[565.0],
    baseline_t=60.0, clip_t_min=20.0
)
# Out:
# saved figs/chip75_ITS_dI_Vgm3p0_565nm_metadata.png
# saved figs/chip75_ITS_dI_Vg3p0_565nm_metadata.png

# %%
BASE = Path("raw_data")
CSV  = "Alisson_15_sept_metadata.csv"
timeline = print_day_timeline(CSV, BASE)
# Out:
# === Day timeline (chronological) ===
#   1  11:38:10  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #1           t=    0.0s
#   2  11:39:13  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #2  +  63.4s  t=   63.4s
#   3  11:40:21  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #3  +  67.3s  t=  130.7s
#   4  11:49:24  LaserCalibration λ=850.0 nm  #1  + 543.5s  t=  674.2s
#   5  11:59:57  LaserCalibration λ=850.0 nm  #2  + 633.0s  t= 1307.2s
#   6  12:16:01  LaserCalibration λ=850.0 nm  #3  + 963.6s  t= 2270.8s
#   7  12:20:05  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #4  + 244.7s  t= 2515.5s
#   8  12:34:15  It  chip 68  VG=-5.04 V  VDS=0.1 V  VL=1.93 V  λ=850.0 nm  period=120.0 s  #1  + 849.5s  t= 3365.1s
#   9  13:13:21  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #5  +2346.2s  t= 5711.2s
#  10  13:16:29  LaserCalibration λ=680.0 nm  #4  + 187.7s  t= 5898.9s
#  11  13:34:18  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #6  +1069.3s  t= 6968.2s
#  12  13:37:13  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #7  + 175.3s  t= 7143.5s
#  13  13:38:44  It  chip 68  VG=-4.81 V  VDS=0.1 V  VL=2.86 V  λ=680.0 nm  period=120.0 s  #2  +  90.5s  t= 7234.0s
#  14  13:43:03  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #8  + 259.0s  t= 7493.0s
#  15  13:47:40  LaserCalibration λ=625.0 nm  #5  + 276.9s  t= 7769.8s
#  16  13:51:34  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #9  + 234.8s  t= 8004.6s
#  17  13:55:00  It  chip 68  VG=-4.7 V  VDS=0.1 V  VL=1.39 V  λ=625.0 nm  period=120.0 s  #3  + 205.3s  t= 8209.9s
#  18  13:58:12  It  chip 68  VG=-4.7 V  VDS=0.1 V  VL=1.39 V  λ=625.0 nm  period=120.0 s  #4  + 192.6s  t= 8402.5s
#  19  14:01:36  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #10  + 204.1s  t= 8606.6s
#  20  14:06:01  LaserCalibration λ=590.0 nm  #6  + 264.6s  t= 8871.2s
#  21  14:10:50  It  chip 68  VG=-4.41 V  VDS=0.1 V  VL=3.76 V  λ=590.0 nm  period=120.0 s  #5  + 288.9s  t= 9160.1s
#  22  14:14:41  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #11  + 231.0s  t= 9391.1s
#  23  14:17:56  LaserCalibration λ=565.0 nm  #7  + 194.8s  t= 9585.9s
#  24  14:21:45  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #12  + 229.8s  t= 9815.6s
#  25  14:23:45  It  chip 68  VG=-5.7 V  VDS=0.1 V  VL=1.53 V  λ=565.0 nm  period=120.0 s  #6  + 119.9s  t= 9935.5s
#  26  14:26:58  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #13  + 192.2s  t=10127.6s
#  27  14:29:29  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #14  + 151.3s  t=10279.0s
#  28  14:33:50  LaserCalibration λ=505.0 nm  #8  + 261.0s  t=10539.9s
#  29  14:39:31  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #15  + 340.8s  t=10880.8s
#  30  14:42:16  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #16  + 165.1s  t=11045.8s
#  31  14:43:21  It  chip 68  VG=-5.77 V  VDS=0.1 V  VL=1.18 V  λ=505.0 nm  period=120.0 s  #7  +  64.8s  t=11110.7s
#  32  14:47:16  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #17  + 235.7s  t=11346.4s
#  33  14:52:02  LaserCalibration λ=455.0 nm  #9  + 285.8s  t=11632.2s
#  34  14:55:15  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #18  + 192.8s  t=11825.0s
#  35  14:56:31  It  chip 68  VG=-4.85 V  VDS=0.1 V  VL=1.29 V  λ=455.0 nm  period=120.0 s  #8  +  75.7s  t=11900.6s
#  36  15:02:42  LaserCalibration λ=405.0 nm  #10  + 371.3s  t=12271.9s
#  37  15:06:18  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #19  + 216.0s  t=12487.9s
#  38  15:08:39  It  chip 68  VG=-4.02 V  VDS=0.1 V  VL=2.92 V  λ=405.0 nm  period=120.0 s  #9  + 141.7s  t=12629.6s
#  39  15:14:50  LaserCalibration λ=385.0 nm  #11  + 370.4s  t=13000.0s
#  40  15:18:46  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #20  + 236.5s  t=13236.6s
#  41  15:20:08  It  chip 68  VG=-6.02 V  VDS=0.1 V  VL=2.21 V  λ=385.0 nm  period=120.0 s  #10  +  81.8s  t=13318.3s
#  42  15:24:26  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #21  + 257.6s  t=13575.9s
#  43  15:25:40  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #22  +  74.3s  t=13650.2s
#  44  15:29:59  LaserCalibration λ=365.0 nm  #12  + 259.0s  t=13909.2s
#  45  15:33:51  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #23  + 231.7s  t=14140.9s
#  46  15:35:24  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #24  +  93.0s  t=14234.0s
#  47  15:37:36  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #25  + 132.4s  t=14366.3s
#  48  15:40:00  It  chip 68  VG=-5.81 V  VDS=0.1 V  VL=3.52 V  λ=365.0 nm  period=120.0 s  #11  + 144.0s  t=14510.3s
#  49  15:43:28  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #26  + 207.3s  t=14717.7s
#  50  15:45:43  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #27  + 135.8s  t=14853.5s
#  51  15:54:47  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #28  + 544.0s  t=15397.5s
#  52  15:55:44  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #29  +  56.7s  t=15454.2s
#  53  16:07:36  LaserCalibration λ=365.0 nm  #13  + 711.7s  t=16165.8s
#  54  16:13:12  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #30  + 336.4s  t=16502.2s
#  55  16:16:04  It  chip 75  VG=-3.87 V  VDS=0.1 V  VL=0.86 V  λ=365.0 nm  period=120.0 s  #12  + 172.3s  t=16674.6s
#  56  16:19:07  It  chip 75  VG=-3.87 V  VDS=0.1 V  VL=1.74 V  λ=365.0 nm  period=120.0 s  #13  + 182.1s  t=16856.7s
#  57  16:22:07  It  chip 75  VG=-3.87 V  VDS=0.1 V  VL=2.68 V  λ=365.0 nm  period=120.0 s  #14  + 180.2s  t=17036.9s
#  58  16:25:07  It  chip 75  VG=-3.87 V  VDS=0.1 V  VL=3.63 V  λ=365.0 nm  period=120.0 s  #15  + 180.2s  t=17217.1s
#  59  16:28:07  It  chip 75  VG=-3.87 V  VDS=0.1 V  VL=4.61 V  λ=365.0 nm  period=120.0 s  #16  + 180.2s  t=17397.3s
#  60  16:31:37  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #31  + 209.9s  t=17607.2s
#  61  16:34:42  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #32  + 184.4s  t=17791.7s
#  62  16:36:44  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #33  + 122.2s  t=17913.9s
# ====================================
#
# saved Alisson_15_sept_metadata_timeline.csv

# %%
METADATA_CSV = "Alisson_15_sept_metadata.csv"        # path to the table you pasted
BASE_DIR     = Path(".")             # where the raw CSVs live, e.g. "Alisson_04_sept/"
CHIP_NUMBER  = 75.0 
meta = load_and_prepare_metadata(METADATA_CSV, CHIP_NUMBER)
tag = Path(METADATA_CSV).stem


plot_its_by_vg_delta(
    meta, BASE_DIR, tag,
    vgs=[-3.87], wavelengths=[365.0],
    baseline_t=60.0, clip_t_min=5.0
)
# Out:
# [warn] missing file: Alisson_15_sept/It2025-09-15_12.csv
# [warn] missing file: Alisson_15_sept/It2025-09-15_13.csv
# [warn] missing file: Alisson_15_sept/It2025-09-15_14.csv
# [warn] missing file: Alisson_15_sept/It2025-09-15_15.csv
# [warn] missing file: Alisson_15_sept/It2025-09-15_16.csv
# [warn] no ITS traces plotted for Vg≈-3.87 V; skipping
