# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import scienceplots
from src.styles import set_plot_style
from src.plots import *
from src.timeline import *
from src.utils import load_and_prepare_metadata
set_plot_style("prism_rain")
from src.utils import _proc_from_path, _file_index, _read_measurement

# %%
METADATA_CSV = "Alisson_12_sept_metadata.csv"        # path to the table you pasted
BASE_DIR     = Path(".")             # where the raw CSVs live, e.g. "Alisson_04_sept/"
CHIP_NUMBER  = 75.0 
meta = load_and_prepare_metadata(METADATA_CSV, CHIP_NUMBER)
tag = Path(METADATA_CSV).stem


# Reuse your existing plotter on this subset
plot_ivg_sequence(meta, BASE_DIR, tag)
# Out:
# saved figs/Encap75_IVg_sequence_Alisson_12_sept_metadata.png

# %%
good_ivgs = [6,7]  # the _NN.csv numbers you want

meta_only_good_ivg = meta.filter(
    (pl.col("proc") == "IVg") & pl.col("file_idx").is_in(good_ivgs)
)

# Reuse your existing plotter on this subset
plot_ivg_sequence(meta_only_good_ivg, BASE_DIR, tag)

# %%
good_ivgs = [7,8]  # the _NN.csv numbers you want

meta_only_good_ivg = meta.filter(
    (pl.col("proc") == "IVg") & pl.col("file_idx").is_in(good_ivgs)
)

# Reuse your existing plotter on this subset
plot_ivg_sequence(meta_only_good_ivg, BASE_DIR, tag)
# Out:
# saved figs/Encap75_IVg_sequence_Alisson_12_sept_metadata.png

# %%
good_ivgs = [9,10]  # the _NN.csv numbers you want

meta_only_good_ivg = meta.filter(
    (pl.col("proc") == "IVg") & pl.col("file_idx").is_in(good_ivgs)
)

# Reuse your existing plotter on this subset
plot_ivg_sequence(meta_only_good_ivg, BASE_DIR, tag)
# Out:
# saved figs/Encap75_IVg_sequence_Alisson_12_sept_metadata.png

# %%
good_ivgs = [10,11]  # the _NN.csv numbers you want

meta_only_good_ivg = meta.filter(
    (pl.col("proc") == "IVg") & pl.col("file_idx").is_in(good_ivgs)
)

# Reuse your existing plotter on this subset
plot_ivg_sequence(meta_only_good_ivg, BASE_DIR, tag)
# Out:
# saved figs/Encap75_IVg_sequence_Alisson_12_sept_metadata.png

# %%
good_ivgs = [11,12,13]  # the _NN.csv numbers you want

meta_only_good_ivg = meta.filter(
    (pl.col("proc") == "IVg") & pl.col("file_idx").is_in(good_ivgs)
)

# Reuse your existing plotter on this subset
plot_ivg_sequence(meta_only_good_ivg, BASE_DIR, tag)
# Out:
# saved figs/Encap75_IVg_sequence_Alisson_12_sept_metadata.png

# %%
good_ivgs = [16,17]  # the _NN.csv numbers you want

meta_only_good_ivg = meta.filter(
    (pl.col("proc") == "IVg") & pl.col("file_idx").is_in(good_ivgs)
)

# Reuse your existing plotter on this subset
plot_ivg_sequence(meta_only_good_ivg, BASE_DIR, tag)
# Out:
# saved figs/Encap75_IVg_sequence_Alisson_12_sept_metadata.png

# %%
good_ivgs = [17,18]  # the _NN.csv numbers you want

meta_only_good_ivg = meta.filter(
    (pl.col("proc") == "IVg") & pl.col("file_idx").is_in(good_ivgs)
)

# Reuse your existing plotter on this subset
plot_ivg_sequence(meta_only_good_ivg, BASE_DIR, tag)
# Out:
# saved figs/Encap75_IVg_sequence_Alisson_12_sept_metadata.png

# %%
good_ivgs = [18,19,20]  # the _NN.csv numbers you want

meta_only_good_ivg = meta.filter(
    (pl.col("proc") == "IVg") & pl.col("file_idx").is_in(good_ivgs)
)

# Reuse your existing plotter on this subset
plot_ivg_sequence(meta_only_good_ivg, BASE_DIR, tag)
# Out:
# saved figs/Encap75_IVg_sequence_Alisson_12_sept_metadata.png

# %%
plot_its_by_vg(meta, BASE_DIR, tag, vgs=[-3.0], wavelengths=[365.0])
# Out:
# saved figs/chip75_ITS_overlay_Vgm3p0_365nm_Alisson_12_sept_metadata.png

# %%
plot_its_by_vg(meta, BASE_DIR, tag, vgs=[3.0], wavelengths=[365.0])
# Out:
# saved figs/chip75_ITS_overlay_Vg3p0_365nm_Alisson_12_sept_metadata.png

# %%
plot_its_by_vg(meta, BASE_DIR, tag, vgs=[-3.0], wavelengths=[455.0]) 
plot_its_by_vg(meta, BASE_DIR, tag, vgs=[3.0], wavelengths=[455.0])
# Out:
# saved figs/chip75_ITS_overlay_Vgm3p0_455nm_Alisson_12_sept_metadata.png
# saved figs/chip75_ITS_overlay_Vg3p0_455nm_Alisson_12_sept_metadata.png

# %%
plot_its_by_vg(meta, BASE_DIR, tag, vgs=[-3.0], wavelengths=[565.0]) 
plot_its_by_vg(meta, BASE_DIR, tag, vgs=[3.0], wavelengths=[565.0])
# Out:
# saved figs/chip75_ITS_overlay_Vgm3p0_565nm_Alisson_12_sept_metadata.png
# saved figs/chip75_ITS_overlay_Vg3p0_565nm_Alisson_12_sept_metadata.png

# %%
BASE = Path(".")
CSV  = "Alisson_12_sept_metadata.csv"
timeline = print_day_timeline(CSV, BASE)
# Out:
# === Day timeline (chronological) ===
#   1  11:14:57  IVg chip 71  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #1
#   2  11:16:25  IVg chip 71  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #2
#   3  11:16:55  IVg chip 71  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #3
#   4  11:19:58  IV  chip 71  VG=0.0 V  VSD:-1.0→1.0 (step 0.01)  #1
#   5  11:20:34  IV  chip 71  VG=0.0 V  VSD:-1.0→1.0 (step 0.01)  #2
#   6  12:49:41  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #4
#   7  13:30:29  LaserCalibration λ=365.0 nm  #1
#   8  13:39:08  LaserCalibration λ=455.0 nm  #2
#   9  13:45:34  LaserCalibration λ=565.0 nm  #3
#  10  13:50:26  LaserCalibration λ=625.0 nm  #4
#  11  14:30:40  LaserCalibration λ=365.0 nm  #5
#  12  14:45:42  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #5
#  13  14:54:38  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #6
#  14  14:56:03  It  chip 75  VG=-3.0 V  VDS=0.1 V  VL=0.88 V  λ=365.0 nm  period=120.0 s  #1
#  15  14:59:10  It  chip 75  VG=-3.0 V  VDS=0.1 V  VL=1.78 V  λ=365.0 nm  period=120.0 s  #2
#  16  15:02:17  It  chip 75  VG=-3.0 V  VDS=0.1 V  VL=2.74 V  λ=365.0 nm  period=120.0 s  #3
#  17  15:05:25  It  chip 75  VG=-3.0 V  VDS=0.1 V  VL=3.71 V  λ=365.0 nm  period=120.0 s  #4
#  18  15:08:32  It  chip 75  VG=-3.0 V  VDS=0.1 V  VL=4.71 V  λ=365.0 nm  period=120.0 s  #5
#  19  15:25:19  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #7
#  20  15:26:53  It  chip 75  VG=3.0 V  VDS=0.1 V  VL=0.88 V  λ=365.0 nm  period=120.0 s  #6
#  21  15:30:00  It  chip 75  VG=3.0 V  VDS=0.1 V  VL=1.78 V  λ=365.0 nm  period=120.0 s  #7
#  22  15:33:07  It  chip 75  VG=3.0 V  VDS=0.1 V  VL=2.74 V  λ=365.0 nm  period=120.0 s  #8
#  23  15:36:14  It  chip 75  VG=3.0 V  VDS=0.1 V  VL=3.71 V  λ=365.0 nm  period=120.0 s  #9
#  24  15:39:22  It  chip 75  VG=3.0 V  VDS=0.1 V  VL=4.71 V  λ=365.0 nm  period=120.0 s  #10
#  25  16:18:01  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #8
#  26  16:25:30  LaserCalibration λ=455.0 nm  #6
#  27  16:31:24  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #9
#  28  16:32:50  It  chip 75  VG=-3.0 V  VDS=0.1 V  VL=0.9 V  λ=455.0 nm  period=120.0 s  #11
#  29  16:35:57  It  chip 75  VG=-3.0 V  VDS=0.1 V  VL=1.71 V  λ=455.0 nm  period=120.0 s  #12
#  30  16:39:04  It  chip 75  VG=-3.0 V  VDS=0.1 V  VL=2.59 V  λ=455.0 nm  period=120.0 s  #13
#  31  16:42:12  It  chip 75  VG=-3.0 V  VDS=0.1 V  VL=3.47 V  λ=455.0 nm  period=120.0 s  #14
#  32  16:45:19  It  chip 75  VG=-3.0 V  VDS=0.1 V  VL=4.42 V  λ=455.0 nm  period=120.0 s  #15
#  33  16:55:23  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #10
#  34  16:56:31  It  chip 75  VG=3.0 V  VDS=0.1 V  VL=0.9 V  λ=455.0 nm  period=120.0 s  #16
#  35  16:59:38  It  chip 75  VG=3.0 V  VDS=0.1 V  VL=1.71 V  λ=455.0 nm  period=120.0 s  #17
#  36  17:02:46  It  chip 75  VG=3.0 V  VDS=0.1 V  VL=2.59 V  λ=455.0 nm  period=120.0 s  #18
#  37  17:05:53  It  chip 75  VG=3.0 V  VDS=0.1 V  VL=3.47 V  λ=455.0 nm  period=120.0 s  #19
#  38  17:09:01  It  chip 75  VG=3.0 V  VDS=0.1 V  VL=4.42 V  λ=455.0 nm  period=120.0 s  #20
#  39  17:15:58  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #11
#  40  17:21:17  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #12
#  41  17:22:14  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #13
#  42  17:23:43  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #14
#  43  17:45:19  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #15
#  44  17:51:22  LaserCalibration λ=565.0 nm  #7
#  45  17:55:44  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #16
#  46  17:57:02  It  chip 75  VG=-3.0 V  VDS=0.1 V  VL=0.78 V  λ=565.0 nm  period=120.0 s  #21
#  47  18:00:10  It  chip 75  VG=-3.0 V  VDS=0.1 V  VL=1.57 V  λ=565.0 nm  period=120.0 s  #22
#  48  18:03:17  It  chip 75  VG=-3.0 V  VDS=0.1 V  VL=2.44 V  λ=565.0 nm  period=120.0 s  #23
#  49  18:06:24  It  chip 75  VG=-3.0 V  VDS=0.1 V  VL=3.38 V  λ=565.0 nm  period=120.0 s  #24
#  50  18:09:31  It  chip 75  VG=-3.0 V  VDS=0.1 V  VL=4.37 V  λ=565.0 nm  period=120.0 s  #25
#  51  18:19:17  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #17
#  52  18:20:18  It  chip 75  VG=3.0 V  VDS=0.1 V  VL=0.78 V  λ=565.0 nm  period=120.0 s  #26
#  53  18:23:26  It  chip 75  VG=3.0 V  VDS=0.1 V  VL=1.57 V  λ=565.0 nm  period=120.0 s  #27
#  54  18:26:34  It  chip 75  VG=3.0 V  VDS=0.1 V  VL=2.44 V  λ=565.0 nm  period=120.0 s  #28
#  55  18:29:41  It  chip 75  VG=3.0 V  VDS=0.1 V  VL=3.38 V  λ=565.0 nm  period=120.0 s  #29
#  56  18:32:48  It  chip 75  VG=3.0 V  VDS=0.1 V  VL=4.37 V  λ=565.0 nm  period=120.0 s  #30
#  57  18:36:18  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #18
#  58  18:37:51  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #19
#  59  18:38:48  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #20
# ====================================
#
# saved Alisson_12_sept_metadata_timeline.csv

# %%
plot_its_by_vg_delta(
    meta, BASE_DIR, tag,
    vgs=[-3.0], wavelengths=[365.0],
    baseline_t=60.0, clip_t_min=20.0
)
plot_its_by_vg_delta(
    meta, BASE_DIR, tag,
    vgs=[3.0], wavelengths=[365.0],
    baseline_t=60.0, clip_t_min=20.0
)
# Out:
# saved figs/chip75_ITS_dI_Vgm3p0_365nm_Alisson_12_sept_metadata.png
# saved figs/chip75_ITS_dI_Vg3p0_365nm_Alisson_12_sept_metadata.png

# %%
plot_its_by_vg_delta(
    meta, BASE_DIR, tag,
    vgs=[-3.0], wavelengths=[455.0],
    baseline_t=60.0, clip_t_min=20.0
)
plot_its_by_vg_delta(
    meta, BASE_DIR, tag,
    vgs=[3.0], wavelengths=[455.0],
    baseline_t=60.0, clip_t_min=20.0
)
# Out:
# saved figs/chip75_ITS_dI_Vgm3p0_455nm_Alisson_12_sept_metadata.png
# saved figs/chip75_ITS_dI_Vg3p0_455nm_Alisson_12_sept_metadata.png

# %%
plot_its_by_vg_delta(
    meta, BASE_DIR, tag,
    vgs=[-3.0], wavelengths=[565.0],
    baseline_t=60.0, clip_t_min=20.0
)
plot_its_by_vg_delta(
    meta, BASE_DIR, tag,
    vgs=[3.0], wavelengths=[565.0],
    baseline_t=60.0, clip_t_min=20.0
)
# Out:
# saved figs/chip75_ITS_dI_Vgm3p0_565nm_Alisson_12_sept_metadata.png
# saved figs/chip75_ITS_dI_Vg3p0_565nm_Alisson_12_sept_metadata.png

# %%
BASE = Path(".")
CSV  = "Alisson_15_sept_metadata.csv"
timeline = print_day_timeline(CSV, BASE)
# Out:
# === Day timeline (chronological) ===
#   1  11:38:10  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #1
#   2  11:39:13  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #2
#   3  11:40:21  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #3
#   4  11:49:24  LaserCalibration λ=850.0 nm  #1
#   5  11:59:57  LaserCalibration λ=850.0 nm  #2
#   6  12:16:01  LaserCalibration λ=850.0 nm  #3
#   7  12:20:05  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #4
#   8  12:34:15  It  chip 68  VG=-5.04 V  VDS=0.1 V  VL=1.93 V  λ=850.0 nm  period=120.0 s  #1
#   9  13:13:21  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #5
#  10  13:16:29  LaserCalibration λ=680.0 nm  #4
#  11  13:34:18  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #6
#  12  13:37:13  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #7
#  13  13:38:44  It  chip 68  VG=-4.81 V  VDS=0.1 V  VL=2.86 V  λ=680.0 nm  period=120.0 s  #2
#  14  13:43:03  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #8
#  15  13:47:40  LaserCalibration λ=625.0 nm  #5
#  16  13:51:34  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #9
#  17  13:55:00  It  chip 68  VG=-4.7 V  VDS=0.1 V  VL=1.39 V  λ=625.0 nm  period=120.0 s  #3
#  18  13:58:12  It  chip 68  VG=-4.7 V  VDS=0.1 V  VL=1.39 V  λ=625.0 nm  period=120.0 s  #4
#  19  14:01:36  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #10
#  20  14:06:01  LaserCalibration λ=590.0 nm  #6
#  21  14:10:50  It  chip 68  VG=-4.41 V  VDS=0.1 V  VL=3.76 V  λ=590.0 nm  period=120.0 s  #5
#  22  14:14:41  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #11
#  23  14:17:56  LaserCalibration λ=565.0 nm  #7
#  24  14:21:45  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #12
#  25  14:23:45  It  chip 68  VG=-5.7 V  VDS=0.1 V  VL=1.53 V  λ=565.0 nm  period=120.0 s  #6
#  26  14:26:58  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #13
#  27  14:29:29  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #14
#  28  14:33:50  LaserCalibration λ=505.0 nm  #8
#  29  14:39:31  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #15
#  30  14:42:16  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #16
#  31  14:43:21  It  chip 68  VG=-5.77 V  VDS=0.1 V  VL=1.18 V  λ=505.0 nm  period=120.0 s  #7
#  32  14:47:16  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #17
#  33  14:52:02  LaserCalibration λ=455.0 nm  #9
#  34  14:55:15  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #18
#  35  14:56:31  It  chip 68  VG=-4.85 V  VDS=0.1 V  VL=1.29 V  λ=455.0 nm  period=120.0 s  #8
#  36  15:02:42  LaserCalibration λ=405.0 nm  #10
#  37  15:06:18  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #19
#  38  15:08:39  It  chip 68  VG=-4.02 V  VDS=0.1 V  VL=2.92 V  λ=405.0 nm  period=120.0 s  #9
#  39  15:14:50  LaserCalibration λ=385.0 nm  #11
#  40  15:18:46  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #20
#  41  15:20:08  It  chip 68  VG=-6.02 V  VDS=0.1 V  VL=2.21 V  λ=385.0 nm  period=120.0 s  #10
#  42  15:24:26  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #21
#  43  15:25:40  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #22
#  44  15:29:59  LaserCalibration λ=365.0 nm  #12
#  45  15:33:51  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #23
#  46  15:35:24  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #24
#  47  15:37:36  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #25
#  48  15:40:00  It  chip 68  VG=-5.81 V  VDS=0.1 V  VL=3.52 V  λ=365.0 nm  period=120.0 s  #11
#  49  15:43:28  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #26
#  50  15:45:43  IVg chip 68  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #27
#  51  15:54:47  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #28
#  52  15:55:44  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #29
#  53  16:07:36  LaserCalibration λ=365.0 nm  #13
#  54  16:13:12  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #30
#  55  16:16:04  It  chip 75  VG=-3.87 V  VDS=0.1 V  VL=0.86 V  λ=365.0 nm  period=120.0 s  #12
#  56  16:19:07  It  chip 75  VG=-3.87 V  VDS=0.1 V  VL=1.74 V  λ=365.0 nm  period=120.0 s  #13
#  57  16:22:07  It  chip 75  VG=-3.87 V  VDS=0.1 V  VL=2.68 V  λ=365.0 nm  period=120.0 s  #14
#  58  16:25:07  It  chip 75  VG=-3.87 V  VDS=0.1 V  VL=3.63 V  λ=365.0 nm  period=120.0 s  #15
#  59  16:28:07  It  chip 75  VG=-3.87 V  VDS=0.1 V  VL=4.61 V  λ=365.0 nm  period=120.0 s  #16
#  60  16:31:37  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #31
#  61  16:34:42  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #32
#  62  16:36:44  IVg chip 75  VDS=0.1 V  VG:-5.0→5.0 (step 0.05)  #33
# ====================================
#
# saved Alisson_15_sept_metadata_timeline.csv

# %%
METADATA_CSV = "Alisson_15_sept_metadata.csv"        # path to the table you pasted
BASE_DIR     = Path(".")             # where the raw CSVs live, e.g. "Alisson_04_sept/"
CHIP_NUMBER  = 75.0 
meta = load_and_prepare_metadata(METADATA_CSV, CHIP_NUMBER)
tag = Path(METADATA_CSV).stem


plot_its_by_vg_delta(
    meta, BASE_DIR, tag,
    vgs=[-3.87], wavelengths=[365.0],
    baseline_t=60.0, clip_t_min=5.0
)
# Out:
# saved figs/chip75_ITS_dI_Vgm3p87_365nm_Alisson_15_sept_metadata.png
